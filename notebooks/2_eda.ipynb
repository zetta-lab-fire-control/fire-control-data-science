# %% [markdown]
# # Desafio 3 - ZettaLab

# %% [markdown]
# ## Análise Exploratória de Dados (EDA)

# %% [markdown]
# ### Importação de Bibliotecas

# %%
import pandas as pd             # Biblioteca para manipulação e análise de dados
import numpy as np              # Biblioteca para calculo de vetores e matrizes
import sys                      # Biblioteca para acessar variaveis e funções que interagem fortemente com o interpretador
import os                       # Biblioteca para interação com arquivos e diretórios a nivel sistema operacional
import basedosdados as bd       # Biblioteca para acessar o datalake público do site BasedosDados
import matplotlib.pyplot as plt
import seaborn as sns
from io import StringIO
from datetime import datetime, timedelta    # 
import requests                 # 

current_dir = os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, '..'))
if parent_dir not in sys.path:
    sys.path.append(parent_dir)
    
import config_path          # Módulo que salva todos os caminhos de diretórios utilizados no projeto

from scripts import features        # Módulo de criação e manipulação de features
from scripts import modeling        # Módulo de modelagem de IA
from scripts import utils           # Módulo de utilitários genéricos
from scripts import pre_processing  # Módulo de pré-processamento e obtenção de dados.

from dotenv import load_dotenv      # Biblioteca para carregar variáveis de ambiente de arquivos .env
load_dotenv()
NASA_FIRMS_API_KEY = os.getenv("NASA_FIRMS_API_KEY") # Coloca a API KEY da NASA FIRMS numa constante

# %%
df_uf_cods = pd.read_csv(config_path.PROCESSED_DATA_DIRECTORY_PATH / "codigos_municipios.csv")
df_mun_cods = pd.read_csv(config_path.PROCESSED_DATA_DIRECTORY_PATH / "codigos_ufs.csv")
df_mun_area = pd.read_csv(config_path.PROCESSED_DATA_DIRECTORY_PATH / "municipio_area_2024.csv")
df_uf_area = pd.read_csv(config_path.PROCESSED_DATA_DIRECTORY_PATH / "uf_area_2024.csv")
df_rg_area = pd.read_csv(config_path.PROCESSED_DATA_DIRECTORY_PATH / "rg_area_2024.csv")
df_inmet_2025 = pd.read_parquet(config_path.PROCESSED_DATA_DIRECTORY_PATH / "df_inmet_2025.parquet")
df_monitor_fogo = pd.read_csv(config_path.PROCESSED_DATA_DIRECTORY_PATH / "monitor-fogo-mapbiomas.csv")
df_dados_BDMEP = pd.read_parquet(config_path.PROCESSED_DATA_DIRECTORY_PATH / "dados_meteorologicos_BDMEP_processado.parquet")
df_banco_queimadas = pd.read_parquet(config_path.PROCESSED_DATA_DIRECTORY_PATH / "banco_dados_queimadas.parquet")

# %%
df_banco_queimadas
# Out:
#                  data_hora           bioma Sigla_UF       Nome_UF  \
# 0      2024-11-12 16:58:00         Cerrado       MG  Minas Gerais
# 1      2024-11-13 04:08:00         Cerrado       MG  Minas Gerais
# 2      2024-11-13 04:08:00         Cerrado       MG  Minas Gerais
# 3      2024-11-20 17:24:00         Cerrado       MG  Minas Gerais
# 4      2024-11-20 17:24:00         Cerrado       MG  Minas Gerais
# ...                    ...             ...      ...           ...
# 377828 2024-10-30 17:39:00  Mata Atlântica       MG  Minas Gerais
# 377829 2024-10-30 17:41:00         Cerrado       MG  Minas Gerais
# 377830 2024-10-30 17:41:00         Cerrado       MG  Minas Gerais
# 377831 2024-10-30 17:41:00         Cerrado       MG  Minas Gerais
# 377832 2024-10-30 17:43:00  Mata Atlântica       MG  Minas Gerais
#
#        ID_Município       Nome_Município  latitude  longitude  satelite  \
# 0           3100104  Abadia dos Dourados -18.38586  -47.36140   NOAA-20
# 1           3100104  Abadia dos Dourados -18.37368  -47.51899   NOAA-20
# 2           3100104  Abadia dos Dourados -18.37182  -47.51684   NOAA-20
# 3           3100104  Abadia dos Dourados -18.35582  -47.42835   NPP-375
# 4           3100104  Abadia dos Dourados -18.35275  -47.42649   NPP-375
# ...             ...                  ...       ...        ...       ...
# 377828      3169406          Três Pontas -21.36878  -45.39243  AQUA_M-T
# 377829      3133402            Itapagipe -19.74592  -49.45157  AQUA_M-T
# 377830      3170206           Uberlândia -19.15206  -47.93509   NOAA-20
# 377831      3171006              Vazante -17.82475  -46.73360  AQUA_M-T
# 377832      3147907               Passos -20.89343  -46.62933   NOAA-20
#
#         dias_sem_chuva  precipitacao  risco_fogo  potencia_radiativa_fogo  \
# 0                  2.0         12.71        0.00                      3.1
# 1                  2.0         12.85        0.00                      1.4
# 2                  2.0         12.80        0.00                      3.0
# 3                  1.0          4.03        0.02                      2.8
# 4                  1.0          4.00        0.02                      4.2
# ...                ...           ...         ...                      ...
# 377828             0.0          0.30        0.03                     18.8
# 377829             0.0          0.00        0.63                      8.4
# 377830             8.0          1.41        0.01                     13.6
# 377831             8.0          5.00        0.00                     11.0
# 377832             0.0          1.30        0.58                     17.8
#
#         ID_UF        Data      Hora   Ano  Mes  Dia
# 0          31  2024-11-12  16:58:00  2024   11   12
# 1          31  2024-11-13  04:08:00  2024   11   13
# 2          31  2024-11-13  04:08:00  2024   11   13
# 3          31  2024-11-20  17:24:00  2024   11   20
# 4          31  2024-11-20  17:24:00  2024   11   20
# ...       ...         ...       ...   ...  ...  ...
# 377828     31  2024-10-30  17:39:00  2024   10   30
# 377829     31  2024-10-30  17:41:00  2024   10   30
# 377830     31  2024-10-30  17:41:00  2024   10   30
# 377831     31  2024-10-30  17:41:00  2024   10   30
# 377832     31  2024-10-30  17:43:00  2024   10   30
#
# [377833 rows x 19 columns]

# %%
df_inmet_2025
# Out:
#                data  hora_utc  precip_total_mm  pressao_atms_nivel_estacao_mB  \
# 0        2025/01/01  0000 UTC              0.0                          886.1
# 1        2025/01/01  0000 UTC              0.0                          919.5
# 2        2025/01/01  0000 UTC              0.0                          982.6
# 3        2025/01/01  0000 UTC              0.0                          929.4
# 4        2025/01/01  0000 UTC              0.0                          918.4
# ...             ...       ...              ...                            ...
# 5020243  2025/12/31  2300 UTC              0.0                         1004.8
# 5020244  2025/12/31  2300 UTC              0.0                          996.8
# 5020245  2025/12/31  2300 UTC              0.0                         1001.6
# 5020246  2025/12/31  2300 UTC              0.0                         1001.6
# 5020247  2025/12/31  2300 UTC              0.0                          897.6
#
#          pressao_atms_maximo_na_hora_mB  pressao_atms_minimo_na_hora_mB  \
# 0                                 886.1                           885.5
# 1                                 919.6                           919.3
# 2                                 982.6                           982.2
# 3                                 929.4                           929.2
# 4                                 918.4                           917.8
# ...                                 ...                             ...
# 5020243                          1004.8                          1004.1
# 5020244                           996.8                           996.0
# 5020245                          1003.3                          1001.6
# 5020246                          1003.3                          1001.6
# 5020247                           898.3                           897.6
#
#          radiacao_global_kj_m  temp_ar_bulbo_seco_C  tempo_ponto_orvarlho_C  \
# 0                         1.7                  20.8                    19.5
# 1                        39.7                  20.5                    19.9
# 2                        12.6                  23.5                    22.0
# 3                        35.3                  20.6                    19.8
# 4                      1003.0                  24.0                    20.6
# ...                       ...                   ...                     ...
# 5020243                   2.1                  27.2                    23.3
# 5020244                  40.7                  27.3                    23.5
# 5020245                2850.5                  30.4                    22.8
# 5020246                2850.5                  30.4                    22.8
# 5020247                 628.2                  23.8                    20.3
#
#          temp_max_hora_C  ...  hora           data_hora  REGIAO  UF  \
# 0                   20.9  ...  0000 2025-01-01 00:00:00      CO  DF
# 1                   20.7  ...  0000 2025-01-01 00:00:00      SE  MG
# 2                   24.2  ...  0000 2025-01-01 00:00:00      SE  MG
# 3                   20.9  ...  0000 2025-01-01 00:00:00      SE  MG
# 4                   24.1  ...  0000 2025-01-01 00:00:00      SE  MG
# ...                  ...  ...   ...                 ...     ...  ..
# 5020243             28.1  ...  2300 2025-12-31 23:00:00       N  AM
# 5020244             28.6  ...  2300 2025-12-31 23:00:00       N  AM
# 5020245             31.0  ...  2300 2025-12-31 23:00:00       N  AM
# 5020246             31.0  ...  2300 2025-12-31 23:00:00       N  AM
# 5020247             24.4  ...  2300 2025-12-31 23:00:00       S  SC
#
#                     ESTACAO  CODIGO (WMO)      LATITUDE     LONGITUDE  \
# 0                  BRASILIA          A001  -15,78944444  -47,92583332
# 1        RIO PARDO DE MINAS          A551  -15,72305554  -42,43583333
# 2                   ITAOBIM          A550  -16,57555554  -41,48555555
# 3           AGUAS VERMELHAS          A549  -15,75166666  -41,45777777
# 4            CHAPADA GAUCHA          A548  -15,30027777  -45,61749999
# ...                     ...           ...           ...           ...
# 5020243            EIRUNEPE          A109   -6,65027777   -69,8686111
# 5020244        BOCA DO ACRE          A110   -8,77666666  -67,33249999
# 5020245              LABREA          A111   -7,26055555   -64,7886111
# 5020246                APUI          A113   -7,20555555   -59,8886111
# 5020247        CAMPOS NOVOS          A898   -27,3886111  -51,21583333
#
#          ALTITUDE DATA DE FUNDACAO
# 0         1160,96         07/05/00
# 1          850,06         17/11/07
# 2          271,63         05/09/07
# 3          754,07         09/09/07
# 4           873,2         22/06/07
# ...           ...              ...
# 5020243    121,54         31/08/12
# 5020244    111,98         15/07/08
# 5020245     61,91         27/07/08
# 5020246    156,97         19/07/08
# 5020247       963         15/02/19
#
# [5020248 rows x 29 columns]

# %%
df_monitor_fogo
# Out:
#         Ano     Bioma              Estado Mes_nome  Mes_num  \
# 0      2019  Amazônia                Acre    Abril        4
# 1      2019  Amazônia                Acre    Abril        4
# 2      2019  Amazônia                Acre   Agosto        8
# 3      2019  Amazônia                Acre   Agosto        8
# 4      2019  Amazônia                Acre   Agosto        8
# ...     ...       ...                 ...      ...      ...
# 25075  2024  Pantanal  Mato Grosso do Sul    Março        3
# 25076  2024  Pantanal  Mato Grosso do Sul    Março        3
# 25077  2024  Pantanal  Mato Grosso do Sul    Março        3
# 25078  2024  Pantanal  Mato Grosso do Sul    Março        3
# 25079  2024  Pantanal  Mato Grosso do Sul    Março        3
#
#       Categoria_principal                        Tipo_uso  \
# 0               Antrópico                    Agropecuária
# 1                 Natural                        Floresta
# 2               Antrópico                    Agropecuária
# 3               Antrópico                    Agropecuária
# 4                 Natural                        Floresta
# ...                   ...                             ...
# 25075           Antrópico                   Corpos D´água
# 25076             Natural                        Floresta
# 25077             Natural                        Floresta
# 25078             Natural  Formação Natural não Florestal
# 25079             Natural  Formação Natural não Florestal
#
#                           Subtipo_uso                       Subclasse  \
# 0                            Pastagem                        Pastagem
# 1                  Formação Florestal              Formação Florestal
# 2                         Agricultura                     Agricultura
# 3                            Pastagem                        Pastagem
# 4                  Formação Florestal               Floresta Alagável
# ...                               ...                             ...
# 25075                          Outros            Rios, Lagos e Oceano
# 25076              Formação Florestal              Formação Florestal
# 25077               Formação Savânica               Formação Savânica
# 25078  Campo Alagado e Área Pantanosa  Campo Alagado e Área Pantanosa
# 25079              Formação Campestre              Formação Campestre
#
#                           Classe_fina                    Classe_final  \
# 0                            Pastagem                        Pastagem
# 1                  Formação Florestal              Formação Florestal
# 2                  Lavoura Temporária     Outras Lavouras Temporárias
# 3                            Pastagem                        Pastagem
# 4                   Floresta Alagável               Floresta Alagável
# ...                               ...                             ...
# 25075            Rios, Lagos e Oceano            Rios, Lagos e Oceano
# 25076              Formação Florestal              Formação Florestal
# 25077               Formação Savânica               Formação Savânica
# 25078  Campo Alagado e Área Pantanosa  Campo Alagado e Área Pantanosa
# 25079              Formação Campestre              Formação Campestre
#
#        Area_queimada_ha
# 0             11.043091
# 1              0.177260
# 2             46.909020
# 3          66041.145360
# 4             68.431673
# ...                 ...
# 25075        381.057779
# 25076        433.061518
# 25077        655.863783
# 25078       2370.983449
# 25079       2375.638107
#
# [25080 rows x 12 columns]

# %%
df_dados_BDMEP
# Out:
#          ano  mes           data_hora    bioma sigla_uf sigla_uf_nome  \
# 0       2025    1 2025-01-18 04:25:00  Cerrado       MG  Minas Gerais
# 1       2025    1 2025-01-20 17:04:00  Cerrado       MG  Minas Gerais
# 2       2025    1 2025-01-21 00:26:00  Cerrado       MG  Minas Gerais
# 3       2025    1 2025-01-21 03:27:00  Cerrado       MG  Minas Gerais
# 4       2025    1 2025-01-21 03:51:00  Cerrado       MG  Minas Gerais
# ...      ...  ...                 ...      ...      ...           ...
# 405027  2023    8 2023-08-31 22:26:33  Cerrado       MG  Minas Gerais
# 405028  2023    8 2023-08-31 22:16:33  Cerrado       MG  Minas Gerais
# 405029  2023    8 2023-08-31 22:06:33  Cerrado       MG  Minas Gerais
# 405030  2023    8 2023-08-31 22:46:33  Cerrado       MG  Minas Gerais
# 405031  2023    8 2023-08-31 03:47:00  Cerrado       MG  Minas Gerais
#
#        id_municipio id_municipio_nome   latitude  longitude  satelite  \
# 0           3100203            Abaeté -19.171250 -45.545000   NOAA-21
# 1           3100203            Abaeté -19.209980 -45.376830   NOAA-20
# 2           3100203            Abaeté -19.216299 -45.369301   METOP-B
# 3           3100203            Abaeté -19.207200 -45.380340   NOAA-21
# 4           3100203            Abaeté -19.206250 -45.380340  NPP-375D
# ...             ...               ...        ...        ...       ...
# 405027      3135209          Januária -15.551200 -44.670100   GOES-16
# 405028      3135209          Januária -15.551200 -44.670100   GOES-16
# 405029      3135209          Januária -15.551200 -44.670100   GOES-16
# 405030      3135209          Januária -15.551200 -44.670100   GOES-16
# 405031      3135209          Januária -15.556130 -44.671610   NOAA-20
#
#         dias_sem_chuva  precipitacao  risco_fogo  potencia_radiativa_fogo  \
# 0                  2.0          0.00        0.00                     0.70
# 1                  3.0          0.45        0.01                     5.40
# 2                  3.0          0.00        0.04                     3.65
# 3                  3.0          0.00        0.03                     1.90
# 4                  3.0          0.00        0.04                     1.50
# ...                ...           ...         ...                      ...
# 405027           120.0          0.00        1.00                   114.40
# 405028           120.0          0.00        1.00                   108.60
# 405029           120.0          0.00        1.00                   101.30
# 405030           120.0          0.00        1.00                    94.10
# 405031           120.0          0.00        1.00                     3.20
#
#               Data      Hora   Ano  Mes  Dia
# 0       2025-01-18  04:25:00  2025    1   18
# 1       2025-01-20  17:04:00  2025    1   20
# 2       2025-01-21  00:26:00  2025    1   21
# 3       2025-01-21  03:27:00  2025    1   21
# 4       2025-01-21  03:51:00  2025    1   21
# ...            ...       ...   ...  ...  ...
# 405027  2023-08-31  22:26:33  2023    8   31
# 405028  2023-08-31  22:16:33  2023    8   31
# 405029  2023-08-31  22:06:33  2023    8   31
# 405030  2023-08-31  22:46:33  2023    8   31
# 405031  2023-08-31  03:47:00  2023    8   31
#
# [405032 rows x 20 columns]

# %%
df_monitor_fogo_mg = df_monitor_fogo.loc[(df_monitor_fogo['Estado'] == 'Minas Gerais'), :]
df_monitor_fogo_mg.reset_index(inplace=True)
df_monitor_fogo_mg.drop(columns=['index'], inplace=True)

# %%
# O foco do trabalho são em incêndios no norte de minas gerais

# %% [markdown]
# ### Geração de Gráficos

# %% [markdown]
# #### Monitor Fogo (2022-2024)

# %%
utils.describe_df(df_monitor_fogo_mg)
# Out:
# Shape: (2055, 12)
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2055 entries, 0 to 2054
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Ano                  2055 non-null   int64
#  1   Bioma                2055 non-null   object
#  2   Estado               2055 non-null   object
#  3   Mes_nome             2055 non-null   object
#  4   Mes_num              2055 non-null   int64
#  5   Categoria_principal  2055 non-null   object
#  6   Tipo_uso             2055 non-null   object
#  7   Subtipo_uso          2055 non-null   object
#  8   Subclasse            2055 non-null   object
#  9   Classe_fina          2055 non-null   object
#  10  Classe_final         2055 non-null   object
#  11  Area_queimada_ha     2055 non-null   float64
# dtypes: float64(1), int64(2), object(9)
# memory usage: 192.8+ KB
# None
#
# Description:
#                Ano      Mes_num  Area_queimada_ha
# count  2055.000000  2055.000000       2055.000000
# mean   2021.338686     6.652555        760.566727
# std       1.643830     3.215251       3151.324835
# min    2019.000000     1.000000          0.083665
# 25%    2020.000000     4.000000          6.019408
# 50%    2021.000000     7.000000         50.735121
# 75%    2023.000000     9.000000        328.695028
# max    2024.000000    12.000000      96640.739819

# %%
valores_area_queimada = df_monitor_fogo.groupby('Tipo_uso')['Area_queimada_ha'].sum()
utils.plot_bar_chart(data=valores_area_queimada.values, 
                     labels=valores_area_queimada.index, 
                     title="Comparação por tipo de uso",
                     path_file=config_path.REPORTS_DIRECTORY_PATH / "1_comparacao_tipo_uso.png")

# %%
df_monitor_fogo_agrupados_ano = df_monitor_fogo.groupby(['Ano'])['Area_queimada_ha'].sum()
utils.plot_pie_chart(data=df_monitor_fogo_agrupados_ano.values,
                     labels=df_monitor_fogo_agrupados_ano.index, 
                     title="Número Total de Hectares Queimados Anualmente no Brasil inteiro entre 2019 a 2024.",
                     path_file=config_path.REPORTS_DIRECTORY_PATH / "2_comparacao_num_total_hec_queimados_ano.png")

# %%
df_monitor_fogo_agrupados_ano = df_monitor_fogo_mg.groupby(['Ano'])['Area_queimada_ha'].sum()
utils.plot_pie_chart(data=df_monitor_fogo_agrupados_ano.values,
                     labels=df_monitor_fogo_agrupados_ano.index, 
                     title="Número Total de Hectares Queimados Anualmente em Minas Gerais entre 2019 a 2024.",
                     path_file=config_path.REPORTS_DIRECTORY_PATH / "3_comparacao_num_total_hec_queimados_ano_mg.png")

# %%
somatorio_area_queimada = df_monitor_fogo_mg.groupby('Mes_nome')['Area_queimada_ha'].sum()
utils.plot_bar_chart(data=somatorio_area_queimada.values, 
                     labels=somatorio_area_queimada.index,
                     title="Número Total de Hectares Queimados por mês em Minas Gerais entre 2019 a 2024.",
                     path_file=config_path.REPORTS_DIRECTORY_PATH / "4_comparacao_num_total_hec_queimados_mes_mg.png")

# %%
df_monitor_fogo_agrupados_ano = df_monitor_fogo_mg.groupby(["Mes_nome", "Tipo_uso"])["Area_queimada_ha"].sum().sort_values(ascending=False).head(5)


utils.plot_pie_chart(data=df_monitor_fogo_agrupados_ano.values,
                     labels=df_monitor_fogo_agrupados_ano.index, 
                     title="Número Total de Hectares Queimados em Minas Gerais entre 2019 a 2024.",
                     path_file=config_path.REPORTS_DIRECTORY_PATH / "5_comparacao_num_total_hec_queimados_mes_tipo_uso_mg.png")

# %%
utils.plot_heatmap(
    df=df_monitor_fogo,
    values='Area_queimada_ha',
    index='Estado',
    columns='Bioma',
    cmap='PuBuGn',
    fmt=".0f",
    title='Área Queimada por Estado e Bioma',
    path_file=config_path.REPORTS_DIRECTORY_PATH / "6_heatmap_area_queimada_estado_bioma.png"
)

# %%
utils.plot_heatmap(
    df=df_monitor_fogo,
    values='Area_queimada_ha',
    index='Mes_nome',
    columns='Ano',
    cmap='YlOrRd',
    title='Área Queimada por Mês e Ano',
    figsize=(12,8),
    path_file=config_path.REPORTS_DIRECTORY_PATH / "7_heatmap_area_queimada_mes_ano.png"
)

# %%
del df_monitor_fogo_agrupados_ano

# %% [markdown]
# #### BDMEP

# %%
df_dados_BDMEP.columns
# Out:
# Index(['ano', 'mes', 'data_hora', 'bioma', 'sigla_uf', 'sigla_uf_nome',
#        'id_municipio', 'id_municipio_nome', 'latitude', 'longitude',
#        'satelite', 'dias_sem_chuva', 'precipitacao', 'risco_fogo',
#        'potencia_radiativa_fogo', 'Data', 'Hora', 'Ano', 'Mes', 'Dia'],
#       dtype='object')

# %%
# Ordenar por município e tempo
df_dados_BDMEP = df_dados_BDMEP.sort_values(by=['id_municipio', 'data_hora'])

# FRP médio por município
df_dados_BDMEP['frp_medio_municipio'] = df_dados_BDMEP.groupby('id_municipio')['potencia_radiativa_fogo'].transform('mean')

# FRP máximo
df_dados_BDMEP['frp_max'] = df_dados_BDMEP.groupby('id_municipio')['potencia_radiativa_fogo'].transform('max')

# FRP normalizado (0 a 1)
df_dados_BDMEP['frp_norm'] = (
    (df_dados_BDMEP['potencia_radiativa_fogo'] - df_dados_BDMEP['potencia_radiativa_fogo'].min()) /
    (df_dados_BDMEP['potencia_radiativa_fogo'].max() - df_dados_BDMEP['potencia_radiativa_fogo'].min())
)

# Índice simples de seca: dias sem chuva / (precipitação + 1)
df_dados_BDMEP['indice_seca'] = df_dados_BDMEP['dias_sem_chuva'] / (df_dados_BDMEP['precipitacao'] + 1)

# Precipitação acumulada 7 dias
df_dados_BDMEP['precipitacao_7d'] = df_dados_BDMEP.groupby('id_municipio')['precipitacao'].transform(lambda x: x.rolling(7, min_periods=1).sum())

# Anomalia de precipitação (z-score por município)
df_dados_BDMEP['anomalia_precipitacao'] = df_dados_BDMEP.groupby('id_municipio')['precipitacao'].transform(lambda x: (x - x.mean()) / x.std())

# Risco suavizado (média móvel 7 dias)
df_dados_BDMEP['risco_movel_7d'] = df_dados_BDMEP.groupby('id_municipio')['risco_fogo'].transform(lambda x: x.rolling(7, min_periods=1).mean())

# Variação diária do risco
df_dados_BDMEP['delta_risco'] = df_dados_BDMEP.groupby('id_municipio')['risco_fogo'].diff()

# Índice composto de risco: risco × seca × FRP normalizado
df_dados_BDMEP['risco_composto'] = df_dados_BDMEP['risco_fogo'] * df_dados_BDMEP['indice_seca'] * df_dados_BDMEP['frp_norm']

# %%
df_dados_BDMEP.head()
# Out:
#         ano  mes           data_hora    bioma sigla_uf sigla_uf_nome  \
# 25786  2022    4 2022-04-26 16:56:00  Cerrado       MG  Minas Gerais
# 25787  2022    4 2022-04-26 16:56:00  Cerrado       MG  Minas Gerais
# 26983  2022    7 2022-07-08 16:39:00  Cerrado       MG  Minas Gerais
# 28173  2022    8 2022-08-12 17:02:00  Cerrado       MG  Minas Gerais
# 29144  2022    9 2022-09-03 16:20:00  Cerrado       MG  Minas Gerais
#
#       id_municipio    id_municipio_nome  latitude  longitude  ... Dia  \
# 25786      3100104  Abadia dos Dourados -18.26171  -47.43314  ...  26
# 25787      3100104  Abadia dos Dourados -18.26036  -47.42374  ...  26
# 26983      3100104  Abadia dos Dourados -18.55436  -47.30458  ...   8
# 28173      3100104  Abadia dos Dourados -18.49137  -47.37548  ...  12
# 29144      3100104  Abadia dos Dourados -18.16959  -47.43729  ...   3
#
#        frp_medio_municipio     frp_max  frp_norm  indice_seca precipitacao_7d  \
# 25786            13.239462  189.166667  0.000793     3.290078             0.0
# 25787            13.239462  189.166667  0.000793     3.290720             0.0
# 26983            13.239462  189.166667  0.000743     4.058272             0.0
# 28173            13.239462  189.166667  0.000694     4.821974             0.0
# 29144            13.239462  189.166667  0.000653     5.445129             0.0
#
#       anomalia_precipitacao  risco_movel_7d  delta_risco  risco_composto
# 25786             -0.255144     -940.984341          NaN       -2.455398
# 25787             -0.255144     -940.920164     0.128353       -2.455412
# 26983             -0.255144     -889.728618   153.510461       -2.374753
# 28173             -0.255144     -825.947760   152.740341       -2.122461
# 29144             -0.255144     -762.753048   124.630984       -1.813649
#
# [5 rows x 29 columns]

# %%
df_dados_BDMEP.to_parquet(config_path.FEATURES_DIRECTORY_PATH / "df_dados_BDMEP.parquet")

# %%
df_mun_area
# Out:
#       ID_UF           Nome_UF UF_SIGLA  ID_Município        Nome_Municipio  \
# 0        11          Rondônia       RO     1101203.0    Ministro Andreazza
# 1        11          Rondônia       RO     1101708.0                 Urupá
# 2        11          Rondônia       RO     1100403.0          Alto Paraíso
# 3        11          Rondônia       RO     1100452.0               Buritis
# 4        11          Rondônia       RO     1101757.0         Vale do Anari
# ...     ...               ...      ...           ...                   ...
# 5568     52             Goiás       GO     5202502.0                Aruanã
# 5569     52             Goiás       GO     5210802.0                 Itajá
# 5570     52             Goiás       GO     5213855.0  Morro Agudo de Goiás
# 5571     52             Goiás       GO     5201207.0            Anhanguera
# 5572     53  Distrito Federal       DF     5300108.0              Brasília
#
#       AreaKm2_Mun_2024
# 0              798.083
# 1              831.857
# 2             2651.991
# 3             3265.810
# 4             3135.106
# ...                ...
# 5568          3054.773
# 5569          2082.737
# 5570           282.333
# 5571            55.569
# 5572          5760.783
#
# [5573 rows x 6 columns]

# %% [markdown]
# #### NASA FIRMS
